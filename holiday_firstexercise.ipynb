# %% [markdown]
# <h1 style="color:red;"> Holiday Prefrences of Rihanna </h1>

# %% [markdown]
# ## TOC:
#
# * [The name of the person](#first-bullet)
# * [Picture of destination](#second-bullet)
# * [10 things to do in Barbados](#third-bullet)
# * [Top 3 things she likes to do in the destination](#fourth-bullet)

# %% [markdown]
# ## Name of the person <a class="anchor" id="first-bullet"></a>

# %%
holiday_person = input("Please enter the name: ")
# Out:
# Please enter the name: rihanna

# %% [markdown]
# ![Rihanna_Fenty_2018.png](attachment:Rihanna_Fenty_2018.png)

# %% [markdown]
# ## Picture of destination <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# ![karibik-barbados-bottom-bay-klein-g-911699158.jpg](attachment:karibik-barbados-bottom-bay-klein-g-911699158.jpg)

# %% [markdown]
# ## 10 things to do in Barbados <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# [10_things_to_do_in_Barbados](https://www.youtube.com/watch?v=nc2mb1LcrGk&pp=ygUIYmFyYmFkb3M%3D/)

# %% [markdown]
# ## Top 3 things she likes to do in the destination <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# ## top_3_things_in_destination:
# * [swimming](#first-bullet)
# * [local_food](#second-bullet)
# * [sunbath](#third-bullet)
